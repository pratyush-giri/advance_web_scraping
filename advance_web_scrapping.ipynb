# %%
with open('smartprix.html','r',encoding = 'utf-8') as f:
  html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder" lang="en" style="--window-width:1036;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#4692F0" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}\n  </script>\n  <script type="application/ld+json">\n   {"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Oppo Reno 8T","url":"https://www.smartprix.com/mobiles/oppo-reno-8t-ppd1lcqaairf","image":["https://cdn1.smartprix.com/rx-i0ogGRPRI-w1200-h1200/0ogGRPRI.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"OnePlus 11 5G","url":"https://www.smartprix.com/mobiles/oneplus-11-5g-ppd12268zbmr","image":["https://cdn1.smartprix.com/rx-iab0UrrCY-w1200-h1200/ab0UrrCY.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"OnePlus 11R","url":"https://www.smartprix.com/mobiles/oneplus-11r-5g-ppd13nudxzb0","image":["https://cdn1.smartprix.com/rx-imx45Jyi7-w1200-h1200/mx45Jyi7.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Samsung Galaxy S23 Ultra 5G","url":"https://www.smartprix.com/mobiles/samsung-galaxy-s23-ultra-5g-ppd1q5mbifnl","image":["https://cdn1.smartprix.com/rx-izLSMVlI0-w1200-h1200/zLSMVlI0.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Vivo Y100","url":"https://www.smartprix.com/mobiles/vivo-y100-ppd1h0e6i8to","image":["https://cdn1.smartprix.com/rx-iS4g6tNdI-w1200-h1200/S4g6tNdI.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Poco X5 Pro","url":"https://www.smartprix.com/mobiles/poco-x5-pro-ppd1q2wepkqk","image":["https://cdn1.smartprix.com/rx-iyUKzqVOE-w1200-h1200/yUKzqVOE.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"OnePlus Nord CE 2 Lite 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-2-lite-5g-ppd1dhnh78au","i ...

# %%
len(soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}))
# Out:
# 1020

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
for i in containers:
  try:
      print(i.find('h2').text)
      print(i.find('span',{'class':'price'}).text)
      print(i.find('div',{'class':'score rank-2-bg'}).find('b').text) 
  except AttributeError as error:
      print(i.find('h2').text)
      print(i.find('span',{'class':'price'}).text)
      try:
        print(i.find('div',{'class':'score rank-1-bg'}).find('b').text) 
      except AttributeError as error:
        print(i.find('div',{'class':'score rank-3-bg'}).find('b').text)
# Out:
# Oppo Reno 8T
# ₹29,999
# 86
# OnePlus 11 5G
# ₹56,999
# 89
# Samsung Galaxy S23 Ultra 5G
# ₹1,24,999
# Samsung Galaxy S23 Ultra 5G
# ₹1,24,999
# 94
# OnePlus Nord CE 2 Lite 5G
# ₹18,999
# 81
# Motorola Moto G62 5G
# ₹14,999
# 81
# Realme 10 Pro Plus
# ₹24,999
# 82
# Realme 10 Pro
# ₹18,999
# 82
# OnePlus Nord 2T 5G
# ₹28,990
# 84
# Samsung Galaxy A14 5G
# ₹16,499
# 75
# Nothing Phone 1
# ₹26,999
# 85
# OnePlus Nord CE 2 Lite 5G (8GB RAM + 128GB)
# ₹19,966
# 84
# Vivo T1 5G (6GB RAM + 128GB)
# ₹16,990
# 80
# Apple iPhone 14
# ₹65,999
# 81
# Xiaomi Redmi Note 12 Pro 5G
# ₹24,990
# 79
# Samsung Galaxy F23 5G (6GB RAM + 128GB)
# ₹14,999
# 80
# OnePlus 11 (16GB RAM + 256GB)
# ₹61,999
# OnePlus 11 (16GB RAM + 256GB)
# ₹61,999
# 90
# Apple iPhone 13
# ₹61,499
# 79
# Samsung Galaxy S23 Plus
# ₹94,999
# 89
# Apple iPhone 14 Pro Max
# ₹1,32,990
# 85
# Xiaomi Redmi Note 12 Pro Plus
# ₹29,999
# 86
# Oppo A78
# ₹18,999
# 79
# Vivo Y16
# ₹9,999
# 65
# OnePlus 10R 5G
# ₹33,999
# 86
# Xiaomi Redmi Note 12
# ₹17,899
# 76
# Apple iPhone 11
# ₹38,999
# 73
# Vivo Y22
# ₹14,499
# 72
# Vivo V25 5G
# ₹27,999
# 83
# Vivo V25 Pro 5G
# ₹35,999
# 85
# Samsung Galaxy S20 FE 5G
# ₹29,999
# 88
# Samsung Galaxy A32 (8GB RAM + 128GB)
# ₹19,849
# 82
# Poco X4 Pro 5G
# ₹15,499
# 80
# Motorola Edge 20 Fusion 5G
# ₹18,999
# 87
# Samsung Galaxy M53 5G
# ₹21,999
# 85
# Poco M4 Pro 5G (6GB RAM + 128GB)
# ₹14,999
# 81
# Realme 10 Pro (8GB RAM + 128GB)
# ₹19,999
# 84
# Xiaomi Redmi Note 11
# ₹11,989
# 76
# Xiaomi Redmi Note 10T 5G (6GB RAM +128GB)
# ₹13,999
# 79
# Realme 10 Pro Plus (8GB RAM + 256GB)
# ₹27,999
# 85
# Vivo Y35
# ₹18,499
# 80
# Realme C33
# ₹8,999
# 64
# OnePlus 10 Pro 5G
# ₹57,490
# 89
# Xiaomi Redmi Note 10S
# ₹10,999
# 78
# Vivo Y16 (4GB RAM + 64GB)
# ₹12,499
# 68
# Samsung Galaxy S22 Ultra 5G
# ₹1,04,999
# Samsung Galaxy S22 Ultra 5G
# ₹1,04,999
# 93
# Realme 9i 5G
# ₹14,399
# 75
# Xiaomi Redmi Note 11 Pro Plus 5G
# ₹19,999
# 83
# Samsung Galaxy M33 5G
# ₹15,999
# 81
# Samsung Galaxy A14 5G (6GB RAM + 128GB)
# ₹18,999
# 79
# Samsung Galaxy S21 FE 5G
# ₹34,999
# 87
# Motorola Moto G82 5G
# ₹18,999
# 83
# Samsung Galaxy S22 5G
# ₹49,999
# 86
# OPPO Reno8 5G
# ₹27,990
# 83
# Realme C33 (4GB RAM + 64GB)
# ₹9,999
# 67
# Motorola Moto G62 (8GB RAM + 128GB)
# ₹15,999
# 84
# Samsung Galaxy A73 5G
# ₹38,700
# Samsung Galaxy A73 5G
# ₹38,700
# 90
# Realme 10 Pro Plus (8GB RAM + 128GB)
# ₹25,999
# 84
# Vivo T1 5G (8GB RAM + 128GB)
# ₹19,990
# 83
# Vivo Y22 (6GB RAM + 128GB)
# ₹16,499
# 75
# Apple iPhone 14 Plus
# ₹74,999
# 82
# Motorola Moto G52
# ₹10,999
# 75
# Realme 10
# ₹13,999
# 74
# Vivo Y21 2021
# ₹12,804
# 69
# OPPO K10 5G
# ₹16,999
# 79
# Samsung Galaxy M13 5G
# ₹13,999
# 75
# Vivo V23 5G (12GB RAM + 256GB)
# ₹27,994
# 86
# iQOO Z6 Lite 5G
# ₹13,499
# 75
# OPPO A17
# ₹12,499
# 72
# Samsung Galaxy S23 Ultra (12GB RAM + 512GB)
# ₹1,34,998
# Samsung Galaxy S23 Ultra (12GB RAM + 512GB)
# ₹1,34,998
# 94
# Xiaomi Redmi 10A (4GB RAM + 64GB)
# ₹8,499
# 66
# OnePlus 10T
# ₹47,999
# 85
# Apple iPhone 13 Pro
# ₹1,19,900
# 83
# OPPO F19 Pro Plus 5G
# ₹17,990
# 82
# Samsung Galaxy A53 5G
# ₹31,999
# 87
# Samsung Galaxy S23 Ultra (12GB RAM + 1TB)
# ₹1,54,998
# Samsung Galaxy S23 Ultra (12GB RAM + 1TB)
# ₹1,54,998
# 95
# Motorola Moto G32
# ₹10,499
# 75
# Vivo T1 5G
# ₹15,990
# 78
# Xiaomi Redmi Note 11 (6GB RAM + 128GB)
# ₹14,442
# 80
# Motorola Edge 30 5G
# ₹22,999
# 83
# Apple iPhone 14 Pro
# ₹1,22,990
# 84
# Infinix Zero Ultra
# ₹32,999
# 89
# Apple iPhone 12
# ₹53,999
# 74
# Apple iPhone 14 Pro
# ₹1,22,990
# 84
# Xiaomi Redmi Note 10 Lite
# ₹9,999
# 76
# OPPO A17K
# ₹9,499
# 62
# Realme GT Neo 3T
# ₹24,980
# 79
# OPPO Reno 8 Pro 5G
# ₹45,999
# 86
# iQOO 11 5G
# ₹59,999
# 88
# Samsung Galaxy M53 5G (8GB RAM + 128GB)
# ₹27,999
# 87
# Realme C35 (6GB RAM + 128GB)
# ₹13,399
# 74
# Xiaomi Redmi 11 Prime 5G
# ₹12,999
# 74
# Samsung Galaxy A14 5G (8GB RAM + 128GB)
# ₹20,999
# 82
# iQOO Neo 6 5G
# ₹27,999
# 82
# Poco M4 Pro 5G
# ₹12,999
# 76
# OPPO K10
# ₹13,990
# 78
# Motorola Moto G72 4G
# ₹15,999
# 82
# Vivo T1 44W (6GB RAM + 128GB)
# ₹15,999
# 79
# Poco X4 Pro 5G (6GB RAM + 128GB)
# ₹16,499
# 82
# Motorola Edge 30 Pro 5G
# ₹34,999
# 89
# Google Pixel 6A
# ₹29,999
# 71
# iQOO Z6 5G
# ₹14,999
# 78
# Xiaomi Redmi K50i 5G
# ₹22,690
# 82
# Samsung Galaxy A33 5G
# ₹25,999
# 82
# Vivo V23 5G
# ₹24,994
# 83
# Xiaomi Redmi A1
# ₹6,252
# Xiaomi Redmi A1
# ₹6,252
# 59
# iQOO Z6 Pro 5G
# ₹21,999
# 78
# Samsung Galaxy A23
# ₹17,486
# 79
# Xiaomi Redmi Note 10S (6GB RAM + 128GB)
# ₹11,999
# 79
# Apple iPhone 11 (128GB)
# ₹45,199
# 75
# Infinix Hot 20
# ₹10,999
# 75
# Samsung Galaxy A23 5G
# ₹21,999
# 79
# OnePlus Nord 2T (12GB RAM + 256GB)
# ₹33,989
# 85
# Motorola Moto G42
# ₹10,999
# 78
# Realme C30
# ₹5,449
# Realme C30
# ₹5,449
# 58
# OnePlus 10R 5G (12GB RAM + 256GB)
# ₹37,998
# 87
# POCO C31 (4GB RAM + 64GB)
# ₹7,499
# 68
# Samsung Galaxy M52 5G
# ₹29,990
# 83
# Xiaomi Redmi Note 12 (6GB RAM + 128GB)
# ₹19,990
# 79
# Motorola Moto E40
# ₹8,300
# 71
# iQOO Z6 Lite (6GB RAM + 128GB)
# ₹15,999
# 79
# Xiaomi Redmi Note 11 Pro Plus 5G (8GB RAM + 256GB)
# ₹23,999
# 87
# Samsung Galaxy F23 5G
# ₹13,999
# 78
# Realme 9i
# ₹13,499
# 75
# OPPO A74 5G
# ₹15,490
# 77
# Samsung Galaxy M33 5G (8GB RAM + 128GB)
# ₹18,590
# 84
# Xiaomi Redmi 10
# ₹9,299
# 71
# iQOO 9 SE 5G
# ₹28,999
# 83
# OPPO F21 Pro 5G
# ₹25,999
# 82
# OPPO A77s
# ₹17,999
# 76
# Nothing Phone 1 (8GB RAM + 256GB)
# ₹27,999
# 86
# Motorola Moto G52 (6GB RAM + 128GB)
# ₹12,999
# 79
# Poco M4 5G
# ₹11,499
# 75
# Realme C35
# ₹11,399
# 70
# Motorola Moto G31
# ₹9,499
# 75
# Realme Narzo 50 Pro 5G
# ₹16,999
# 81
# Apple iPhone 12 Mini
# ₹41,999
# 74
# Samsung Galaxy F13
# ₹9,699
# 74
# iQOO 7
# ₹24,990
# 83
# Infinix Note 12i (2022)
# ₹9,999
# 73
# Motorola Edge 30 Ultra
# ₹54,999
# Motorola Edge 30 Ultra
# ₹54,999
# 92
# Tecno Phantom X2
# ₹39,999
# 85
# Vivo V25 (12GB RAM + 256GB)
# ₹31,999
# 85
# Infinix Zero 20
# ₹15,999
# 87
# Infinix Note 12 5G
# ₹12,999
# 78
# Realme 9 5G
# ₹15,650
# 75
# Apple iPhone 13 Pro Max
# ₹1,29,900
# 84
# Vivo Y02
# ₹8,999
# Vivo Y02
# ₹8,999
# 54
# Apple iPhone 14 Pro Max (256GB)
# ₹1,42,999
# 86
# Tecno Pova 3
# ₹9,999
# 74
# POCO M4 Pro 4G
# ₹10,999
# 77
# Samsung Galaxy A32
# ₹19,800
# 80
# Realme 10 (8GB RAM + 128GB)
# ₹16,999
# 79
# Vivo Y75 5G
# ₹21,990
# 82
# Xiaomi Redmi Note 11SE
# ₹11,999
# 80
# Xiaomi Redmi 10 Power
# ₹12,299
# 77
# POCO C31
# ₹6,499
# 65
# Xiaomi Redmi Note 12 Pro (8GB RAM + 256GB)
# ₹27,999
# 82
# Motorola Moto G82 (8GB RAM + 128GB)
# ₹20,499
# 86
# Poco X4 Pro 5G (8GB RAM + 128GB)
# ₹17,499
# 84
# Samsung Galaxy A13
# ₹14,499
# 75
# Google Pixel 6 Pro
# ₹48,000
# 89
# Samsung Galaxy S23 (8GB RAM + 256GB)
# ₹79,998
# 88
# Samsung Galaxy A04e
# ₹9,299
# 65
# Nothing Phone 1 (12GB RAM + 256GB)
# ₹35,999
# 87
# Vivo T1 44W
# ₹14,499
# 77
# Vivo T1x 4G
# ₹11,999
# 74
# Realme 9 Pro 5G
# ₹18,999
# 80
# iKall Z19 Pro
# ₹7,999
# 60
# Samsung Galaxy F04
# ₹8,999
# 68
# Google Pixel 7 Pro 5G
# ₹80,999
# Google Pixel 7 Pro 5G
# ₹80,999
# 90
# OnePlus 10 Pro 5G (12GB RAM + 256GB)
# ₹65,200
# OnePlus 10 Pro 5G (12GB RAM + 256GB)
# ₹65,200
# 90
# Infinix Hot 20 (6GB RAM+ 128GB)
# ₹12,999
# 78
# Apple iPhone 14 Pro Max (1TB)
# ₹1,82,999
# 87
# Vivo V25 Pro (12GB RAM + 256GB)
# ₹39,999
# 86
# Samsung Galaxy M13 5G (4GB RAM + 64GB)
# ₹11,999
# 71
# OPPO A57 4G (4GB RAM + 64 GB)
# ₹13,989
# 69
# Xiaomi Redmi Note 11 (6GB RAM + 64GB)
# ₹12,394
# 79
# Realme 9 Pro Plus 5G
# ₹24,999
# 78
# Vivo V23 Pro 5G
# ₹31,994
# 85
# Vivo Y16 (3GB RAM + 64GB)
# ₹10,499
# 66
# Realme 9i 5G (6GB RAM + 128GB)
# ₹16,399
# 78
# Samsung Galaxy M04
# ₹8,940
# 66
# Poco M4 5G (6GB RAM + 128GB)
# ₹13,499
# 79
# iQOO Z6 5G (6GB RAM + 128GB)
# ₹17,449
# 80
# Google Pixel 7 5G
# ₹50,890
# 86
# Xiaomi Redmi Note 11T 5G (6GB RAM + 128GB)
# ₹16,999
# 81
# Samsung Galaxy A23 5G (8GB RAM + 128GB)
# ₹23,999
# 81
# OPPO F21s Pro 4G
# ₹20,880
# 82
# Vivo T1 Pro 5G (8GB RAM + 128GB)
# ₹24,999
# 84
# Realme Narzo 50
# ₹11,500
# 74
# Motorola Edge 30 5G (8GB RAM + 128GB)
# ₹24,990
# 85
# Motorola Edge 30 Fusion 5G
# ₹39,999
# 88
# Samsung Galaxy A03
# ₹7,249
# 67
# Xiaomi 12 Pro 5G
# ₹47,490
# 89
# Samsung Galaxy S22 Plus 5G
# ₹59,999
# 87
# Realme 9 4G
# ₹16,840
# 81
# Apple iPhone 12 (128GB)
# ₹56,999
# 75
# Samsung Galaxy A73 5G (8GB RAM + 256GB)
# ₹44,999
# Samsung Galaxy A73 5G (8GB RAM + 256GB)
# ₹44,999
# 90
# OPPO Reno7 Pro 5G
# ₹31,994
# 87
# Apple iPhone 13 Mini
# ₹64,900
# 79
# OnePlus 9 Pro
# ₹64,800
# 89
# Infinix Hot 20 Play
# ₹8,299
# 67
# Lava Blaze 5G
# ₹10,999
# 73
# Vivo T1x (6GB RAM + 128GB)
# ₹14,999
# 77
# Samsung Galaxy M13
# ₹11,699
# 75
# Poco M4 Pro 5G (8GB RAM + 128GB)
# ₹15,999
# 82
# Samsung Galaxy Note 20 Ultra 5G
# ₹79,499
# Samsung Galaxy Note 20 Ultra 5G
# ₹79,499
# 93
# Samsung Galaxy Note 10 Plus
# ₹59,999
# 89
# Samsung Galaxy S10 Plus
# ₹39,880
# 81
# Samsung Galaxy A53 (8GB RAM + 256GB)
# ₹36,499
# 89
# Motorola Moto E32s
# ₹7,780
# 65
# Samsung Galaxy A33 5G (8GB RAM + 128GB)
# ₹25,476
# 85
# Samsung Galaxy A23 (8GB RAM + 128GB)
# ₹18,999
# 82
# Xiaomi Redmi Note 11 Pro Plus 5G (8GB RAM + 128GB)
# ₹21,999
# 86
# Vivo V23e 5G
# ₹21,680
# 84
# Motorola Moto G51 5G
# ₹12,999
# 77
# Xiaomi Mi 11 Lite NE 5G
# ₹20,990
# 83
# Jio JioPhone Next
# ₹4,699
# Jio JioPhone Next
# ₹4,699
# 54
# Samsung Galaxy S21 Ultra
# ₹1,05,999
# Samsung Galaxy S21 Ultra
# ₹1,05,999
# 93
# Tecno Pova 4
# ₹11,999
# 73
# Infinix Note 12 Pro
# ₹14,999
# 83
# Xiaomi Redmi Note 10T 5G
# ₹12,999
# 75
# Google Pixel 6
# ₹41,710
# 84
# Tecno Phantom X2 Pro
# ₹49,999
# 89
# Vivo Y75 4G
# ₹19,990
# 82
# Realme C31 (4GB RAM + 64GB)
# ₹9,689
# 65
# Tecno Spark 9
# ₹8,999
# 69
# Motorola Moto G22
# ₹9,499
# 75
# Motorola Edge 30 Ultra (12GB RAM + 256GB)
# ₹59,999
# Motorola Edge 30 Ultra (12GB RAM + 256GB)
# ₹59,999
# 94
# Apple iPhone 14 (256GB)
# ₹75,999
# 82
# OnePlus 10T (16GB RAM + 256GB)
# ₹53,739
# 87
# Samsung Galaxy A04
# ₹11,999
# 71
# Samsung Galaxy A13 (4GB RAM + 128GB)
# ₹14,999
# 75
# Samsung Galaxy A53 5G (8GB RAM + 128GB)
# ₹33,499
# 89
# Motorola Moto E32
# ₹8,989
# 71
# Poco F4 5G
# ₹27,999
# 82
# Xiaomi Redmi Note 12 Pro (8GB RAM + 128GB)
# ₹26,999
# 82
# Xiaomi Redmi Note 10 Pro (6GB RAM + 128GB)
# ₹17,999
# 81
# Poco X3
# ₹13,499
# 80
# OPPO A55 4G (4GB RAM + 128GB)
# ₹13,999
# 74
# Poco C50
# ₹6,249
# Poco C50
# ₹6,249
# 59
# iQOO 11 (16GB RAM + 256GB)
# ₹64,999
# 89
# Samsung Galaxy Z Fold 4
# ₹1,46,999
# Samsung Galaxy Z Fold 4
# ₹1,46,999
# 91
# Motorola Moto G71 5G
# ₹16,930
# 80
# Xiaomi Redmi 10 (6GB RAM + 128GB)
# ₹11,499
# 75
# Xiaomi Redmi 10A
# ₹7,499
# 64
# iQOO 9 5G
# ₹39,990
# 84
# Vivo Y01A
# ₹7,750
# 60
# Xiaomi Redmi 11 Prime 5G (6GB RAM + 128GB)
# ₹15,999
# 77
# OPPO A77
# ₹15,499
# 70
# Nokia 2660 Flip
# ₹4,499
# Nokia 2660 Flip
# ₹4,499
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6c896a070be1> in <module>
#       4       print(i.find('span',{'class':'price'}).text)
# ----> 5       print(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
#       6   except AttributeError as error:
#
# AttributeError: 'NoneType' object has no attribute 'find'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6c896a070be1> in <module>
#       9       try:
# ---> 10         print(i.find('div',{'class':'score rank-1-bg'}).find('b').text)
#      11       except AttributeError as error:
#
# AttributeError: 'NoneType' object has no attribute 'find'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6c896a070be1> in <module>
#      10         print(i.find('div',{'class':'score rank-1-bg'}).find('b').text)
#      11       except AttributeError as error:
# ---> 12         print(i.find('div',{'class':'score rank-3-bg'}).find('b').text)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                             model      price rating  \
# 0                    Oppo Reno 8T    ₹29,999     86
# 1                   OnePlus 11 5G    ₹56,999     89
# 2     Samsung Galaxy S23 Ultra 5G  ₹1,24,999    NaN
# 3       OnePlus Nord CE 2 Lite 5G    ₹18,999     81
# 4            Motorola Moto G62 5G    ₹14,999     81
# ...                           ...        ...    ...
# 1015            Snexian Guru 2163       ₹699    NaN
# 1016                  Cellecor E1     ₹1,149    NaN
# 1017                      Vox V10       ₹774    NaN
# 1018                      Vox V12       ₹699    NaN
# 1019                 Angage A2320       ₹799    NaN
#
#                                                 sim  \
# 0           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 3                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                             ...
# 1015                                       Dual Sim
# 1016                                       Dual Sim
# 1017                                       Dual Sim
# 1018                                       Dual Sim
# 1019                                       Dual Sim
#
#                                               processor  \
# 0          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1       Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 2     Snapdragon 8 Gen 2, Octa Core, 3.36 GHz Processor
# 3          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 4         Snapdragon  695, Octa Core, 2.2 GHz Processor
# ...                                                 ...
# 1015                                              No 3G
# 1016                                  1.5 MHz Processor
# 1017                           32 MB RAM, 32 MB inbuilt
# 1018                           32 MB RAM, 32 MB inbuilt
# 1019                           64 MB RAM, 64 MB inbuilt
#
#                             ram                                   battery  \
# 0      8 GB RAM, 128 GB inbuilt   4800 mAh Battery with 67W Fast Charging
# 1      8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 2     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 4      6 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# ...                         ...                                       ...
# 1015          1.4 MHz Processor                  32 MB RAM, 32 MB inbuilt
# 1016   32 MB RAM, 32 MB inbuilt                          1000 mAh Battery
# 1017           2500 mAh Battery          1.8 inches, 180 x 320 px Display
# 1018            800 mAh Battery          1.8 inches, 180 x 260 px Display
# 1019           1100 mAh Battery         1.77 inches, 128 x 160 px Display
#
#                                                 display  \
# 0     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 2     6.8 inches, 1440 x 3088 px, 120 Hz Display wit...
# 3     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 4     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# ...                                                 ...
# 1015                                    850 mAh Battery
# 1016                   1.8 inches, 128 x 160 px Display
# 1017                                 0.3 MP Rear Camera
# 1018                                 0.3 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                                  camera  \
# 0     108 MP + 2 MP + 2 MP Triple Rear & 32 MP Front...
# 1     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 2                 200 MP Quad Rear & 12 MP Front Camera
# 3     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# ...                                                 ...
# 1015                  1.77 inches, 120 x 240 px Display
# 1016                                 0.8 MP Rear Camera
# 1017                                                NaN
# 1018                                                NaN
# 1019                  Memory Card Supported, upto 32 GB
#
#                                    card           os
# 0      Memory Card Supported, upto 1 TB  Android v13
# 1             Memory Card Not Supported  Android v13
# 2             Memory Card Not Supported  Android v13
# 3       Memory Card (Hybrid), upto 1 TB  Android v12
# 4       Memory Card (Hybrid), upto 1 TB  Android v12
# ...                                 ...          ...
# 1015                   1 MP Rear Camera          NaN
# 1016  Memory Card Supported, upto 32 GB          NaN
# 1017                                NaN          NaN
# 1018                                NaN          NaN
# 1019                                NaN          NaN
#
# [1020 rows x 11 columns]
